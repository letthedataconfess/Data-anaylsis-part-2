# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv("Iris.csv")

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.shape
# Out:
# (150, 6)

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
df['Species'].value_counts()
# Out:
# Iris-versicolor    50
# Iris-setosa        50
# Iris-virginica     50
# Name: Species, dtype: int64

# %%
df.corr()
# Out:
#                      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Id             1.000000       0.716676     -0.397729       0.882747
# SepalLengthCm  0.716676       1.000000     -0.109369       0.871754
# SepalWidthCm  -0.397729      -0.109369      1.000000      -0.420516
# PetalLengthCm  0.882747       0.871754     -0.420516       1.000000
# PetalWidthCm   0.899759       0.817954     -0.356544       0.962757
#
#                PetalWidthCm
# Id                 0.899759
# SepalLengthCm      0.817954
# SepalWidthCm      -0.356544
# PetalLengthCm      0.962757
# PetalWidthCm       1.000000

# %%
import seaborn as sns
sns.regplot(x="PetalLengthCm",y='PetalWidthCm',data=df)

# %%
x=df['PetalLengthCm']   ## only for quantitative analysis
sns.distplot(x,hist=True,bins=5,kde=True,rug=True,norm_hist=False)

# %%
from scipy.stats import norm
x_pw = df['PetalWidthCm']
sns.distplot(x_pw,hist=True,bins=5,kde=True,rug=True,norm_hist=False,fit=norm)  #https://seaborn.pydata.org/generated/seaborn.distplot.html

# %%
sns.boxplot(x='Species',y='PetalLengthCm',data=df)  #https://seaborn.pydata.org/generated/seaborn.boxplot.html

# %%
sns.boxplot(y='PetalLengthCm',data=df)

# %%
sns.barplot(x='Species',y='PetalLengthCm',data=df)

# %%
ax = sns.barplot(x="PetalLengthCm", y="PetalWidthCm", hue="Species", data=df)   #https://seaborn.pydata.org/generated/seaborn.barplot.html

# %%
sns.countplot(x='SepalLengthCm',data=df,hue="Species")    #https://seaborn.pydata.org/generated/seaborn.countplot.html#seaborn.countplot

# %%
sns.lineplot(x='Species',y='PetalLengthCm',data=df)  #shows relationship when one variable is categorical #https://seaborn.pydata.org/generated/seaborn.lineplot.html

# %%
sns.lineplot(x="PetalWidthCm", y="PetalLengthCm", hue="Species",data=df)

# %%
sns.lineplot(x="SepalLengthCm", y="SepalWidthCm", hue="Species",data=df)     #https://seaborn.pydata.org/generated/seaborn.lineplot.html

# %%
sns.pointplot(x='Species',y='PetalLengthCm',data=df)

# %%
sns.scatterplot(x="PetalLengthCm",y='PetalWidthCm',data=df)

# %%
sns.pairplot(data=df)   #https://seaborn.pydata.org/generated/seaborn.pairplot.html
